# %%
import pandas as pd

# %% [markdown]
# ## Strongly labelled dataset
# **Train set**
#
# Audioset comes as a csv file containing youtube IDs (below segment_id), start/end times of the segment, and a class label ID.
#
# - Youtube IDs identify a youtube URL as: https://www.youtube.com/watch?v={YOUTUBE_ID}
# - Class label ID needs to be matched with the ontology dataset to have the verbose description
#
# While for the visually indicated sounds workstream we are not neceassarily interested in the labels, the dataset is still helpful as it provides a backbone list of video-audio links to be downloaded.

# %%
df = pd.read_csv('audioset_data/audioset_train_strong.tsv', sep='\t')
df
# Out:
#                segment_id  start_time_seconds  end_time_seconds       label
# 0       b0RFKhbpFJA_30000               0.000            10.000  /m/03m9d0z
# 1       b0RFKhbpFJA_30000               4.753             5.720   /m/05zppz
# 2       b0RFKhbpFJA_30000               0.000            10.000  /m/07pjwq1
# 3       b0RFKhbpFJA_30000               6.899             7.010  /m/07qjznt
# 4       b0RFKhbpFJA_30000               8.534             9.156  /t/dd00092
# ...                   ...                 ...               ...         ...
# 934816  cq-vfngNXMc_70000               7.836             8.015  /m/07qjznt
# 934817  cq-vfngNXMc_70000               8.226             8.511  /t/dd00099
# 934818  cq-vfngNXMc_70000               8.503             8.868   /m/05zppz
# 934819  cq-vfngNXMc_70000               9.217             9.624  /t/dd00099
# 934820  cq-vfngNXMc_70000               9.778            10.000  /t/dd00099
#
# [934821 rows x 4 columns]

# %%
df['diff'] = df.end_time_seconds - df.start_time_seconds
df['diff'].describe()
# Out:
# count    934821.000000
# mean          2.059805
# std           3.221891
# min           0.000000
# 25%           0.220000
# 50%           0.552000
# 75%           1.753000
# max          10.000000
# Name: diff, dtype: float64

# %%
segment_ids = df.segment_id.unique()
for video_url in segment_ids:
    video_df = df[df['segment_id']==video_url]
    start_time = video_df.start_time_seconds.min()
    end_time = video_df.end_time_seconds.max()
    print(start_time)
    print(end_time)
    ## DOWNLOAD VIDEO

    for segment in video_df.iterrows():
        segment_id = segment[1][0]
        start_time = segment[1][1]
        end_time = segment[1][2]
        label = segment[1][3]


    break
# Out:
# 0.0
# 10.0
# 10.0
# 5.72
# 10.0
# 7.01
# 9.156
# C:\Users\giorg\AppData\Local\Temp\ipykernel_15628\1027679705.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   segment_id = segment[1][0]
# C:\Users\giorg\AppData\Local\Temp\ipykernel_15628\1027679705.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   start_time = segment[1][1]
# C:\Users\giorg\AppData\Local\Temp\ipykernel_15628\1027679705.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   end_time = segment[1][2]
# C:\Users\giorg\AppData\Local\Temp\ipykernel_15628\1027679705.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label = segment[1][3]

# %% [markdown]
# Each video has labels for multiple segments. The total number of segments is 139538, while the total number of videos is:

# %%
df.segment_id.nunique()
# Out:
# 103463

# %% [markdown]
# Each segment is labelled with a class that identified by a label id (e.g. /m/07pggtn). The id-name correspondance can be found in the ontology file

# %%
onto = pd.read_json('audioset_data/ontology.json')

print(f"Number of classes: {len(onto)}")

onto.head()
# Out:
# Number of classes: 632
#           id                           name  \
# 0  /m/0dgw9r                   Human sounds
# 1   /m/09l8g                    Human voice
# 2   /m/09x0r                         Speech
# 3  /m/05zppz      Male speech, man speaking
# 4   /m/02zsn  Female speech, woman speaking
#
#                                          description  \
# 0  Sounds produced by the human body through the ...
# 1  The human voice consists of sound made by a hu...
# 2  Speech is the vocalized form of human communic...
# 3             Speech uttered by an adult male human.
# 4           Speech uttered by an adult female human.
#
#                                citation_uri  \
# 0
# 1  http://en.wikipedia.org/wiki/Human_voice
# 2       http://en.wikipedia.org/wiki/Speech
# 3
# 4
#
#                                    positive_examples  \
# 0                                                 []
# 1                                                 []
# 2  [youtu.be/8uI9H5jGRV8?start=30&end=40, youtu.b...
# 3  [youtu.be/6niRPYpLOpQ?start=30&end=40, youtu.b...
# 4  [youtu.be/4l05nCOnIRg?start=30&end=40, youtu.b...
#
#                                            child_ids restrictions
# 0  [/m/09l8g, /m/01w250, /m/09hlz4, /m/0bpl036, /...   [abstract]
# 1  [/m/09x0r, /m/07p6fty, /m/03qc9zr, /m/02rtxlg,...   [abstract]
# 2  [/m/05zppz, /m/02zsn, /m/0ytgt, /m/01h8n0, /m/...           []
# 3                                                 []           []
# 4                                                 []           []

# %%
df = pd.merge(df, onto[['id','name','description']], how='left', left_on='label', right_on='id')

df = df.drop(columns=['id'])

df
# Out:
#                segment_id  start_time_seconds  end_time_seconds       label  \
# 0       b0RFKhbpFJA_30000               0.000            10.000  /m/03m9d0z
# 1       b0RFKhbpFJA_30000               4.753             5.720   /m/05zppz
# 2       b0RFKhbpFJA_30000               0.000            10.000  /m/07pjwq1
# 3       b0RFKhbpFJA_30000               6.899             7.010  /m/07qjznt
# 4       b0RFKhbpFJA_30000               8.534             9.156  /t/dd00092
# ...                   ...                 ...               ...         ...
# 934816  cq-vfngNXMc_70000               7.836             8.015  /m/07qjznt
# 934817  cq-vfngNXMc_70000               8.226             8.511  /t/dd00099
# 934818  cq-vfngNXMc_70000               8.503             8.868   /m/05zppz
# 934819  cq-vfngNXMc_70000               9.217             9.624  /t/dd00099
# 934820  cq-vfngNXMc_70000               9.778            10.000  /t/dd00099
#
#                              name  \
# 0                            Wind
# 1       Male speech, man speaking
# 2                            Buzz
# 3                            Tick
# 4         Wind noise (microphone)
# ...                           ...
# 934816                       Tick
# 934817      Generic impact sounds
# 934818  Male speech, man speaking
# 934819      Generic impact sounds
# 934820      Generic impact sounds
#
#                                               description
# 0       Sounds caused by the large-scale flow of gases...
# 1                  Speech uttered by an adult male human.
# 2       The sound of rapid vibration, commonly the win...
# 3                               A metallic tapping sound.
# 4       The noise produced when a strong air current p...
# ...                                                   ...
# 934816                          A metallic tapping sound.
# 934817  Sounds of impacts or collisions preferentially...
# 934818             Speech uttered by an adult male human.
# 934819  Sounds of impacts or collisions preferentially...
# 934820  Sounds of impacts or collisions preferentially...
#
# [934821 rows x 6 columns]

# %% [markdown]
# The 10 most present labels are:

# %%
df.groupby('name').count()[['segment_id']].sort_values('segment_id', ascending=False).head(10)
# Out:
#                                          segment_id
# name
# Generic impact sounds                        131725
# Male speech, man speaking                    101509
# Tick                                          57020
# Female speech, woman speaking                 36065
# Breathing                                     31606
# Music                                         30930
# Mechanisms                                    27411
# Background noise                              21162
# Wind noise (microphone)                       18834
# Bird vocalization, bird call, bird song       16732

# %%
df.groupby('name').count()[['segment_id']].sort_values('segment_id', ascending=False).tail(10)
# Out:
#                            segment_id
# name
# Wildfire                            2
# Wobble                              2
# Zing                                1
# Puff                                1
# Outside, urban or manmade           1
# Deformable shell                    1
# Inside, small room                  1
# Human locomotion                    1
# Sonic boom                          1
# Grind                               1

# %% [markdown]
# One issue with the dataset: a segment can have multiple labels (e.g. Male speech, man speaking)

# %% [markdown]
# ## Original dataset
#
# this dataset is the original (from 2017) audioset dataset. This version is not strongly labelled, but can still serve our purpose. In this dataset, 1 row = 1 video

# %%
df1 = pd.read_csv('audioset_data/eval_segments.csv')

# %%
df1
# Out:
#             # YTID   start_seconds   end_seconds  positive_labels  Unnamed: 4  \
# 0      --4gqARaEJE             0.0          10.0        "/m/068hy  /m/07q6cd_
# 1      --BfvyPmVMo            20.0          30.0       "/m/03l9g"         NaN
# 2      --U7joUcTCo             0.0          10.0      "/m/01b_21"         NaN
# 3      --i-y1v8Hy8             0.0           9.0        "/m/04rlf    /m/09x0r
# 4      -0BIyqJj9ZU            30.0          40.0      "/m/07rgt08  /m/07sq110
# ...            ...             ...           ...              ...         ...
# 20366  zyF8TGSRvns           150.0         160.0        "/m/0dwsp    /m/0dwtp
# 20367  zz35Va7tYmA            30.0          40.0       "/m/012f08  /m/07q2z82
# 20368  zzD_oVgzKMc            30.0          40.0     "/m/07pn_8q"         NaN
# 20369  zzNdwF40ID8            70.0          80.0        "/m/04rlf   /m/0790c"
# 20370  zzbTaK7CXJY            30.0          40.0      "/m/03m9d0z  /m/07qwyj0
#
#         Unnamed: 5   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0        /m/0bt9lr     /m/0jbk"        NaN        NaN        NaN         NaN
# 1              NaN          NaN        NaN        NaN        NaN         NaN
# 2              NaN          NaN        NaN        NaN        NaN         NaN
# 3       /t/dd00004  /t/dd00005"        NaN        NaN        NaN         NaN
# 4      /t/dd00001"          NaN        NaN        NaN        NaN         NaN
# ...            ...          ...        ...        ...        ...         ...
# 20366    /m/0f8s22  /m/0j45pbj"        NaN        NaN        NaN         NaN
# 20367   /m/07qmpdm     /m/0k4j"        NaN        NaN        NaN         NaN
# 20368          NaN          NaN        NaN        NaN        NaN         NaN
# 20369          NaN          NaN        NaN        NaN        NaN         NaN
# 20370  /t/dd00092"          NaN        NaN        NaN        NaN         NaN
#
#       Unnamed: 11
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 20366         NaN
# 20367         NaN
# 20368         NaN
# 20369         NaN
# 20370         NaN
#
# [20371 rows x 12 columns]

# %%
df1 = pd.read_csv('audioset_data/balanced_train_segments.csv')

# %%
df1
# Out:
#             # YTID   start_seconds   end_seconds  positive_labels  \
# 0      --PJHxphWEs            30.0          40.0        "/m/09x0r
# 1      --ZhevVpy1s            50.0          60.0      "/m/012xff"
# 2      --aE2O5G5WE             0.0          10.0        "/m/03fwl
# 3      --aO5cdqSAg            30.0          40.0      "/t/dd00003
# 4      --aaILOrkII           200.0         210.0       "/m/032s66
# ...            ...             ...           ...              ...
# 22155  zyqg4pYEioQ            20.0          30.0        "/m/09x0r
# 22156  zz0ddNfz0h0            30.0          40.0       "/m/012f08
# 22157  zz8TGV83nkE            80.0          90.0       "/m/012f08
# 22158  zzlK8KDqlr0           370.0         380.0        "/m/01m2v
# 22159  zzya4dDVRLk            30.0          40.0       "/m/01v_m0
#
#         Unnamed: 4 Unnamed: 5   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0      /t/dd00088"        NaN          NaN        NaN        NaN        NaN
# 1              NaN        NaN          NaN        NaN        NaN        NaN
# 2         /m/04rlf  /m/09x0r"          NaN        NaN        NaN        NaN
# 3      /t/dd00005"        NaN          NaN        NaN        NaN        NaN
# 4       /m/073cg4"        NaN          NaN        NaN        NaN        NaN
# ...            ...        ...          ...        ...        ...        ...
# 22155    /m/0llzx"        NaN          NaN        NaN        NaN        NaN
# 22156    /m/03cl9h   /m/07yv9     /m/0k4j"        NaN        NaN        NaN
# 22157     /m/02mk9   /m/04_sv    /m/07yv9"        NaN        NaN        NaN
# 22158   /m/07qc9xj   /m/09x0r  /t/dd00125"        NaN        NaN        NaN
# 22159    /m/0hdsk"        NaN          NaN        NaN        NaN        NaN
#
#       Unnamed: 10 Unnamed: 11
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
# ...           ...         ...
# 22155         NaN         NaN
# 22156         NaN         NaN
# 22157         NaN         NaN
# 22158         NaN         NaN
# 22159         NaN         NaN
#
# [22160 rows x 12 columns]
